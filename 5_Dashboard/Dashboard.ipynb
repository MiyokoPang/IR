# %%
import subprocess
import sys

print("🚀 Launching Unified Dashboard...")
# This runs the updated dashboard.py file
cmd = [sys.executable, "-m", "streamlit", "run", "dashboard.py"]

try:
    process = subprocess.Popen(cmd)
    print("✅ Dashboard running! Open: http://localhost:8501")
    process.wait()
except KeyboardInterrupt:
    process.terminate()
# Out:
# 🚀 Launching Unified Dashboard...
# ✅ Dashboard running! Open: http://localhost:8501
